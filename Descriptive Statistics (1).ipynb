# %%
target_url = ("https://archive.ics.uci.edu/ml/machine-learning-databases/00488/")
data = urllib2.urlopen(target_url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1fce1be91135> in <module>()
#       1 target_url = ("https://archive.ics.uci.edu/ml/machine-learning-databases/00488/")
# ----> 2 data = urllib2.urlopen(target_url)
#
# NameError: name 'urllib2' is not defined

# %%
import urllib

# %%
target_url = ("https://archive.ics.uci.edu/ml/machine-learning-databases/00488/")
data = urllib.request.urlopen(target_url)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-154461d671a8> in <module>()
#       1 target_url = ("https://archive.ics.uci.edu/ml/machine-learning-databases/00488/")
# ----> 2 data = urllib.request.urlopen(target_url)
#
# AttributeError: module 'urllib' has no attribute 'request'

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %%
df = pd.read_csv("Z:\live.csv")

# %%
df.head(10)
# Out:
#                           status_id status_type status_published  \
# 0  246675545449582_1649696485147474       video   4/22/2018 6:00
# 1  246675545449582_1649426988507757        link  4/21/2018 22:45
# 2  246675545449582_1648730588577397       video   4/21/2018 6:17
# 3  246675545449582_1648576705259452      status   4/21/2018 2:29
# 4  246675545449582_1645700502213739       photo   4/18/2018 3:22
# 5  246675545449582_1645650162218773       photo   4/18/2018 2:14
# 6  246675545449582_1645564175560705       video   4/18/2018 0:24
# 7  246675545449582_1644824665634656       video   4/17/2018 7:42
# 8  246675545449582_1644655795651543       photo   4/17/2018 3:33
# 9  246675545449582_1638788379571618       photo   4/11/2018 4:53
#
#    num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0            529           512         262        432         92         3
# 1            150             0           0        150         20         0
# ...

# %%
df.describe()
# Out:
#        status_id\tstatus_type\tstatus_published\tnum_reactions\tnum_comments\tnum_shares\tnum_likes\tnum_loves\tnum_wows\tnum_hahas\tnum_sads\tnum_angrys\tColumn1\tColumn2\tColumn3\tColumn4
# count                                                7050
# unique                                               6999
# top     819700534875473_965614580284067\tphoto\t4/7/20...
# freq                                                    2

# %%
df['num_reactions'].hist(bins=50)

# %%
df.boxplot('num_reactions')

# %%
df.boxplot(column='num_shares', by = 'status_type')

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df
# Out:
#      status_id\tstatus_type\tstatus_published\tnum_reactions\tnum_comments\tnum_shares\tnum_likes\tnum_loves\tnum_wows\tnum_hahas\tnum_sads\tnum_angrys\tColumn1\tColumn2\tColumn3\tColumn4
# 0     246675545449582_1649696485147474\tvideo\t4/22/...
# 1     246675545449582_1649426988507757\tphoto\t4/21/...
# 2     246675545449582_1648730588577397\tvideo\t4/21/...
# 3     246675545449582_1648576705259452\tphoto\t4/21/...
# 4     246675545449582_1645700502213739\tphoto\t4/18/...
# 5     246675545449582_1645650162218773\tphoto\t4/18/...
# 6     246675545449582_1645564175560705\tvideo\t4/18/...
# 7     246675545449582_1644824665634656\tvideo\t4/17/...
# 8     246675545449582_1644655795651543\tphoto\t4/17/...
# 9     246675545449582_1638788379571618\tphoto\t4/11/...
# 10    246675545449582_1637655039684952\tphoto\t4/10/...
# 11    246675545449582_1636730006444122\tphoto\t4/9/2...
# 12    246675545449582_1635846033199186\tphoto\t4/8/2...
# ...

# %%
status = df["status_type"].head(4)
likes = df["num_loves"].head(4)
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728"]
explode = (0.1, 0, 0, 0)  
plt.pie(df['status_type'].value_counts().tolist(), labels=df['status_type'].unique().tolist(), colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Types of Status")
plt.show()

# %%
from scipy import stats
stats.iqr(df.num_likes)
# Out:
# 167.75

# %%
describe(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-cc906b12b39e> in <module>()
# ----> 1 describe(df)
#
# NameError: name 'describe' is not defined

# %%
df.describe()
# Out:
#        num_reactions  num_comments   num_shares    num_likes    num_loves  \
# count    7050.000000   7050.000000  7050.000000  7050.000000  7050.000000
# mean      230.117163    224.356028    40.022553   215.043121    12.728652
# std       462.625309    889.636820   131.599965   449.472357    39.972930
# min         0.000000      0.000000     0.000000     0.000000     0.000000
# 25%        17.000000      0.000000     0.000000    17.000000     0.000000
# 50%        59.500000      4.000000     0.000000    58.000000     0.000000
# 75%       219.000000     23.000000     4.000000   184.750000     3.000000
# max      4710.000000  20990.000000  3424.000000  4710.000000   657.000000
#
#           num_wows    num_hahas     num_sads   num_angrys  Column1  Column2  \
# count  7050.000000  7050.000000  7050.000000  7050.000000      0.0      0.0
# mean      1.289362     0.696454     0.243688     0.113191      NaN      NaN
# ...

# %%
df.mean()
# Out:
# status_id               inf
# num_reactions    230.117163
# num_comments     224.356028
# num_shares        40.022553
# num_likes        215.043121
# num_loves         12.728652
# num_wows           1.289362
# num_hahas          0.696454
# num_sads           0.243688
# num_angrys         0.113191
# Column1                 NaN
# Column2                 NaN
# Column3                 NaN
# Column4                 NaN
# dtype: float64

# %%
stats.hmean(df.num_likes.head(5))
# Out:
# 179.89227436670146

# %%
stats.gmean(df.num_likes.head(5))
# Out:
# 197.34751580528703

# %%
d=df['status_type'].value_counts().tolist()

# %%
d
# Out:
# [4286, 2334, 366, 64]

# %%
d.count
